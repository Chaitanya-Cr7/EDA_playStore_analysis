# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya-Cr7/EDA_playStore_analysis/blob/main/Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ps_data = pd.read_csv('/content/Play Store Data.csv')

# %%
ps_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
ps_data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
ps_data.shape
# Out:
# (10841, 13)

# %%
ps_data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
ps_data.boxplot()

# %%
ps_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0e869b2090>]],
#       dtype=object)

# %% [markdown]
# CLEANING THE DATA

# %%
ps_data.info
# Out:
# <bound method DataFrame.info of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]>

# %% [markdown]
# Checking The Number Of Outliers

# %%
ps_data[ps_data.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
ps_data.drop([10472], inplace=True)

# %%
ps_data.boxplot();

# %% [markdown]
# Removing Null Values

# %%
ps_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
ps_data['Rating'].fillna(ps_data['Rating'].median(), inplace=True)

# %%
print(ps_data.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
ps_data=ps_data[ps_data['Type'].notna()]

# %%
ps_data=ps_data[ps_data['Current Ver'].notna()]

# %%
ps_data=ps_data[ps_data['Android Ver'].notna()]

# %%
print(ps_data.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# CHECKING THE DUPLICATIONS OF SAME APP

# %%
boolean = ps_data['App'].duplicated().any()
boolean
# Out:
# True

# %%
ps_data['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# Candy Crush Saga                                      7
# 8 Ball Pool                                           7
# ESPN                                                  7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9648, dtype: int64

# %% [markdown]
# CHECKING THE REDUNDANT VALUES

# %%
ps_data[ps_data['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
# 1701  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1841   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1870   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2016   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2088   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2206   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 4527   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up
# 1701  2.347.225742  4.1 and up
# 1748  2.347.225742  4.1 and up
# 1841  2.347.225742  4.1 and up
# 1870  2.347.225742  4.1 and up
# 2016  2.347.225742  4.1 and up
# 2088  2.347.225742  4.1 and up
# 2206  2.347.225742  4.1 and up
# 4527  2.347.225742  4.1 and up

# %% [markdown]
# Due To The Redundant Similar Rows, Keeping The Rows With Maximum Reviews From an App

# %%
ps_data.drop_duplicates(subset='App',inplace=True)

# %%
ps_data['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# Candy Crush Saga                                      7
# 8 Ball Pool                                           7
# ESPN                                                  7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9648, dtype: int64

# %%
ps_data[ps_data['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up

# %%
ps_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9648 non-null   object
#  1   Category        9648 non-null   object
#  2   Rating          9648 non-null   float64
#  3   Reviews         9648 non-null   object
#  4   Size            9648 non-null   object
#  5   Installs        9648 non-null   object
#  6   Type            9648 non-null   object
#  7   Price           9648 non-null   object
#  8   Content Rating  9648 non-null   object
#  9   Genres          9648 non-null   object
#  10  Last Updated    9648 non-null   object
#  11  Current Ver     9648 non-null   object
#  12  Android Ver     9648 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
ps_data[ps_data['Reviews'] =='3.0M']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
ps_data['Reviews'] =ps_data.Reviews.replace("0.0",0)
ps_data['Reviews'] =ps_data.Reviews.replace("3.0M",3000000.0)
ps_data['Reviews'] =ps_data['Reviews'].astype(float)
ps_data['Reviews'].dtype
# Out:
# dtype('float64')

# %%
ps_data['Reviews'].unique()
# Out:
# array([1.59000e+02, 9.67000e+02, 8.75100e+04, ..., 6.03000e+02,
#        1.19500e+03, 3.98307e+05])

# %%
ps_data['Size'].max(),ps_data['Size'].min()
# Out:
# ('Varies with device', '1.0M')

# %%
ps_data['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M',
#        '11M', '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M',
#        '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M',
#        '5.7M', '8.6M', '2.4M', '27M', '2.7M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '80M', '1.7M', '74M',
#        '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M', '71M',
#        '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k', '899k',
#        '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M', '89M',
#        '696k', '544k', '525k', '920k', '779k', '853k', '720k', '713k',
#        '772k', '318k', '58k', '241k', '196k', '857k', '51k', '953k',
#        '865k', '251k', '930k', '540k', '313k', '746k', '203k', '26k',
#        '314k', '239k', '371k', '220k', '730k', '756k', '91k', '293k',
#        '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k', '81k',
#        '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '219k', '55k', '948k', '323k', '691k',
#        '511k', '951k', '963k', '25k', '554k', '351k', '27k', '82k',
#        '208k', '913k', '514k', '551k', '29k', '103k', '898k', '743k',
#        '116k', '153k', '209k', '353k', '499k', '173k', '597k', '809k',
#        '122k', '411k', '400k', '801k', '787k', '50k', '643k', '986k',
#        '97k', '516k', '837k', '780k', '961k', '269k', '20k', '498k',
#        '600k', '749k', '642k', '881k', '72k', '656k', '601k', '221k',
#        '228k', '108k', '940k', '176k', '33k', '663k', '34k', '942k',
#        '259k', '164k', '458k', '245k', '629k', '28k', '288k', '775k',
#        '785k', '636k', '916k', '994k', '309k', '485k', '914k', '903k',
#        '608k', '500k', '54k', '562k', '847k', '957k', '688k', '811k',
#        '270k', '48k', '329k', '523k', '921k', '874k', '981k', '784k',
#        '280k', '24k', '518k', '754k', '892k', '154k', '860k', '364k',
#        '387k', '626k', '161k', '879k', '39k', '970k', '170k', '141k',
#        '160k', '144k', '143k', '190k', '376k', '193k', '246k', '73k',
#        '992k', '253k', '420k', '404k', '470k', '226k', '240k', '89k',
#        '234k', '257k', '861k', '467k', '157k', '44k', '676k', '67k',
#        '552k', '885k', '1020k', '582k', '619k'], dtype=object)

# %%
ps_data['Size'] =ps_data.Size.replace("Varies with device",np.nan)
ps_data['Size'] =ps_data.Size.str.replace("M","000")

# %%
ps_data['Size'] =ps_data.Size.replace("Varies with device",np.nan)
# All size values became  kilobyte type.
ps_data['Size'] =ps_data.Size.str.replace("M","000") 
ps_data['Size'] =ps_data.Size.str.replace("k","")
ps_data['Size'] =ps_data.Size.replace("1,000+",1000)
ps_data['Size'] =ps_data['Size'].astype(float)
ps_data['Size'].dtype
# Out:
# dtype('float64')

# %%
ps_data['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
ps_data['Price'] =ps_data.Price.replace("Everyone",np.nan)
ps_data['Price'] =ps_data.Price.str.replace("$","").astype(float)
ps_data['Price'].dtype
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# dtype('float64')

# %%
ps_data['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+'], dtype=object)

# %%
ps_data['Installs'] =ps_data.Installs.str.replace(",","")
ps_data['Installs'] =ps_data.Installs.str.replace("+","")
ps_data['Installs'] =ps_data.Installs.replace("Free",np.nan)
ps_data['Installs'] =ps_data['Installs'].astype(float)
ps_data['Installs'].dtype
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# dtype('float64')

# %%
ps_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating               0
# Reviews              0
# Size              1226
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
print(ps_data['Size'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-27442d6720c4> in <module>()
# ----> 1 print(ps_data['Size'].mean())
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#   10372
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10353             )
#   10354         return self._reduce(
# > 10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#   10357
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
ps_data['Size'].fillna(str(ps_data['Size'].mean()),inplace=True)

# %%
ps_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# USER REVIEW

# %%
User_Rev =pd.read_csv('/content/User Reviews.csv')

# %%
User_Rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
User_Rev.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
User_Rev.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
User_Rev.shape
# Out:
# (64295, 5)

# %%
User_Rev.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
User_Rev=User_Rev[User_Rev['Translated_Review'].notna()]

# %%
User_Rev.shape
# Out:
# (37427, 5)

# %% [markdown]
# MERGED DATA

# %%
Merged_df=pd.merge(ps_data,User_Rev,on='App')
Merged_df
# Out:
#                                 App        Category  Rating   Reviews  \
# 0               Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 1               Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 2               Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 3               Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 4               Coloring book moana  ART_AND_DESIGN     3.9     967.0
# ...                             ...             ...     ...       ...
# 35924  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 35925  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 35926  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 35927  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 35928  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
#
#                     Size    Installs  Type  Price Content Rating  \
# 0                14000.0    500000.0  Free    0.0       Everyone
# 1                14000.0    500000.0  Free    0.0       Everyone
# 2                14000.0    500000.0  Free    0.0       Everyone
# 3                14000.0    500000.0  Free    0.0       Everyone
# 4                14000.0    500000.0  Free    0.0       Everyone
# ...                  ...         ...   ...    ...            ...
# 35924  18390.90555687487  10000000.0  Free    0.0       Everyone
# 35925  18390.90555687487  10000000.0  Free    0.0       Everyone
# 35926  18390.90555687487  10000000.0  Free    0.0       Everyone
# 35927  18390.90555687487  10000000.0  Free    0.0       Everyone
# 35928  18390.90555687487  10000000.0  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 3      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 4      Art & Design;Pretend Play  January 15, 2018               2.0.0
# ...                          ...               ...                 ...
# 35924                Photography    August 6, 2018  Varies with device
# 35925                Photography    August 6, 2018  Varies with device
# 35926                Photography    August 6, 2018  Varies with device
# 35927                Photography    August 6, 2018  Varies with device
# 35928                Photography    August 6, 2018  Varies with device
#
#               Android Ver                                  Translated_Review  \
# 0            4.0.3 and up  A kid's excessive ads. The types ads allowed a...
# 1            4.0.3 and up                                         It bad >:(
# 2            4.0.3 and up                                               like
# 3            4.0.3 and up                           I love colors inspyering
# 4            4.0.3 and up                                             I hate
# ...                   ...                                                ...
# 35924  Varies with device           Overall great app. Best gallery seen far
# 35925  Varies with device  Recommended, 100% love it, keep good work dev ...
# 35926  Varies with device                                       Too much ads
# 35927  Varies with device                                Just allow time ...
# 35928  Varies with device                       It's good best gallery phone
#
#       Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0      Negative           -0.250000                1.000000
# 1      Negative           -0.725000                0.833333
# 2       Neutral            0.000000                0.000000
# 3      Positive            0.500000                0.600000
# 4      Negative           -0.800000                0.900000
# ...         ...                 ...                     ...
# 35924  Positive            0.475000                0.512500
# 35925  Positive            0.566667                0.733333
# 35926  Positive            0.200000                0.200000
# 35927   Neutral            0.000000                0.000000
# 35928  Positive            0.850000                0.450000
#
# [35929 rows x 17 columns]

# %%
Merged_df.isnull().sum()
# Out:
# App                       0
# Category                  0
# Rating                    0
# Reviews                   0
# Size                      0
# Installs                  0
# Type                      0
# Price                     0
# Content Rating            0
# Genres                    0
# Last Updated              0
# Current Ver               0
# Android Ver               0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
Merged_df['Rating'].fillna(Merged_df['Rating'].mean(), inplace=True)

# %%
Merged_df.shape
# Out:
# (35929, 17)

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
# FINDING THE TOP 20 APPS IN PLAY STORE AS PER GENRES

# %%
top_genres = ps_data.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})
genres_installs = ps_data.groupby(['Genres'])[['Installs']].sum()

# %%
top_genres_installs = pd.merge(top_genres, genres_installs, on='Genres')
top_20_genres_installs = top_genres_installs.sort_values('Count',ascending=False)[0:20]

# %%
top_20_genres_installed = top_genres_installs.sort_values('Installs',ascending=False)[0:20]

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("Top 20 Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Count)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x2 = ps_data['Content Rating'].value_counts().index
y2 = ps_data['Content Rating'].value_counts()

x2sis = []
y2sis = []
for i in range(len(x2)):
    x2sis.append(x2[i])
    y2sis.append(y2[i])

# %%
plt.figure(figsize=(10,12))
plt.bar(x2sis,y2sis,width=0.9,color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2'], alpha=0.9);
plt.title('Content Rating',size = 30);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %% [markdown]
# sentiment_subjectivity

# %%
sentimet_subjectivity_polarity = Merged_df.groupby(['Category'])['Sentiment_Polarity','Sentiment_Subjectivity'].mean().reset_index().rename(columns={'Sentiment_Polarity':'Sentiment_polarity_avg','Sentiment_Subjectivity':'sentiment_subjectivity_avg'})

Merged_df['Sentiment_Subjectivity'] = Merged_df['Sentiment_Subjectivity'].abs()
Merged_df['Sentiment_Polarity'] = Merged_df['Sentiment_Polarity'].abs()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(10,12))
sns.scatterplot(Merged_df['Sentiment_Subjectivity'], Merged_df['Sentiment_Polarity'])
plt.title("Does sentiment_subjectivity proportional to sentiment_polarity")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Category vs Installs

# %%
grp=ps_data.groupby('Category')
x=grp['Installs'].agg(np.sum)
y=grp['Price'].agg(np.sum)
z=grp['Reviews'].agg(np.mean)

# %%
plt.figure(figsize=(13,6))
plt.plot(x ,  color='red')
plt.xticks(rotation=90)
plt.title('Category vs Installs')
plt.xlabel('Categories-------->')
plt.ylabel('Installs-------->')
plt.grid()
plt.show()

# %% [markdown]
# Category Vs Reviews

# %%
plt.figure(figsize=(10,5))
plt.plot(z ,'y^',  color='y')
plt.xticks(rotation=90)
plt.title('Category vs Reviews')
plt.xlabel('Categories-------->')
plt.ylabel('Reviews-------->')
plt.show()

# %% [markdown]
# # Category vs Pricing

# %%
plt.figure(figsize=(17,12))
plt.plot(y ,'c--',  color='c')
plt.xticks(rotation=90)
plt.title('Category vs Pricing')
plt.xlabel('Categories-------->')
plt.ylabel('Prices-------->')
plt.show()

# %% [markdown]
# # Paid vs Free Apps

# %%
# Paid vs Free
def impute_type(cols):
    Type = cols[0]
       
    if Type == '0':
        return 'Free'
    
    else: 
        return Type

# %%
ps_data['Type'] = ps_data[['Type']].apply(impute_type, axis = 1)

# %%
plt.figure(figsize=(6,9))
sns.countplot(x = 'Type', data = ps_data)

# %% [markdown]
# # **Ratings**

# %%
plt.figure(figsize=(18, 6))
plt.title('Overall user rating of the app')
plt.xlabel('Ratings')
plt.ylabel('Number of users')

plt.hist(ps_data.Rating, bins=np.arange(1,5,0.5), color='green');

# %%
fig, ax = plt.subplots(figsize=(6, 7), subplot_kw=dict(aspect="equal"))

number_of_apps = ps_data['Type'].value_counts()

labels = number_of_apps.index
sizes = number_of_apps.values

ax.pie(sizes,labeldistance=2,autopct='%1.1f%%')
ax.legend(labels=labels,loc="right",bbox_to_anchor=(0.9, 0, 0.5, 1))
ax.axis("equal")
plt.title('Type Distribution')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 7), subplot_kw=dict(aspect="equal"))

number_of_apps = ps_data['Content Rating'].value_counts()

labels = number_of_apps.index
sizes = number_of_apps.values

ax.pie(sizes,labeldistance=2,autopct='%1.1f%%')
ax.legend(labels=labels,loc="right",bbox_to_anchor=(0.9, 0, 0.5, 1))
ax.axis("equal")
plt.title('Content Distributation')
plt.show()

# %% [markdown]
# # Top 10 Apps with highest no of installs

# %%
new_df=ps_data[ps_data['Installs']==ps_data['Installs'].max()]

new=new_df.groupby('App')['Installs'].sum()
new=new.reset_index()
new=new.sort_values(by=['Installs'],ascending=False)
new_=new.head(10)

# %%
plt.bar(new_['App'],new_['Installs'])
plt.xticks(rotation=75)
plt.title('Top 10 Apps with highest no of installs')
plt.xlabel('Apps')
plt.ylabel('No of installs')
# Out:
# Text(0, 0.5, 'No of installs')

# %% [markdown]
# # Top 10 Apps with highest number of reviews

# %%
highest_no_of_reviews = ps_data.groupby('App')[['Reviews']].mean().sort_values('Reviews', ascending=False).head(10)

highest_no_of_reviews
# Out:
#                                                        Reviews
# App
# Facebook                                            78158306.0
# WhatsApp Messenger                                  69119316.0
# Instagram                                           66577313.0
# Messenger – Text and Video Chat for Free            56642847.0
# Clash of Clans                                      44891723.0
# Clean Master- Space Cleaner & Antivirus             42916526.0
# Subway Surfers                                      27722264.0
# YouTube                                             25655305.0
# Security Master - Antivirus, VPN, AppLock, Booster  24900999.0
# Clash Royale                                        23133508.0

# %%
sns.barplot(highest_no_of_reviews.index, highest_no_of_reviews.Reviews)

plt.title('Top 10 Apps with highist number of reviews')
plt.xticks(rotation=75);
plt.ylabel(None);
plt.xlabel('Category');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Facebook, WhatsApp and instagram has highest no of Reviews in google platy store
# What are top 10 category having highest number of installs ?

# %%
top_category = Merged_df.Category.value_counts().reset_index().rename(columns={'Category':'Count','index':'Category'})
category_installs = Merged_df.groupby(['Category'])[['Installs']].sum()
top_category_installs = pd.merge(top_category, category_installs, on='Category')
top_10_category_installs = top_category_installs[0:11]

# %%
top_10_category_installs
# Out:
#               Category  Count      Installs
# 0                 GAME   6678  4.262736e+11
# 1   HEALTH_AND_FITNESS   2249  1.796420e+10
# 2               FAMILY   2009  2.424934e+10
# 3               DATING   1715  2.046310e+09
# 4     TRAVEL_AND_LOCAL   1692  2.973330e+10
# 5               SPORTS   1479  6.835990e+09
# 6         PRODUCTIVITY   1463  9.680830e+10
# 7                TOOLS   1451  1.105238e+11
# 8              FINANCE   1435  1.450589e+10
# 9              MEDICAL   1400  7.519640e+08
# 10       ENTERTAINMENT   1264  9.114450e+09

# %% [markdown]
# # Correlation Map

# %%
# Correlation map
f,ax = plt.subplots(figsize=(15,10))
sns.heatmap(ps_data.corr(), annot=True, linewidths=.8, fmt= '.2f',ax=ax)
plt.show()

# %% [markdown]
# # We can determine from above that Installs and Reviews are Positively Correlated.

# %%
plt.figure(figsize=(12,8))
fig=sns.regplot(x='Price',y='Rating',data=ps_data[ps_data['Reviews']<1000000],color='orange')
fig.set_xlabel("Price",size=15)
fig.set_ylabel("Ratings",size=15)
plt.xticks(size=10)
plt.yticks(size=10)
plt.title('Price vs Ratings',size = 20)
plt.tight_layout()

# %% [markdown]
# # Generally increasing the Prices doesn't have significant effect on Higher Rating. For Higher Price, Rating is High and almost constant ie greater than 4

# %%
plt.figure(figsize=(12,8))
fig=sns.regplot(x='Reviews',y='Rating',data=ps_data[ps_data['Reviews']<1000000],color='orange')
fig.set_xlabel("Reviews<1000000",size=15)
fig.set_ylabel("Ratings",size=15)
plt.xticks(size=10)
plt.yticks(size=10)
plt.title('Reviews vs Ratings',size = 20)
plt.tight_layout()

# %% [markdown]
# # As per the above scatter plot with the trendline we can conclude that lesser reviews on applications will decrease the rating as well.

# %% [markdown]
# # Reviews vs Installs

# %%
plt.scatter(ps_data['Reviews'], ps_data['Rating'])
plt.title('Reviews vs Installs')
plt.xlabel('Reviews')
plt.ylabel('Installs')
plt.show()

# %% [markdown]
# # Size vs Installs

# %%
plt.scatter(ps_data['Size'], ps_data['Rating'])
plt.title('Size vs Installs')
plt.xlabel('Size')
plt.ylabel('Installs')
plt.show()

# %% [markdown]
# # Free vs Paid Apps

# %%
ps_data.groupby('Type').count()
# Out:
#        App  Category  Rating  Reviews  Size  Installs  Price  Content Rating  \
# Type
# Free  8895      8895    8895     8895  8895      8895   8895            8895
# Paid   753       753     753      753   753       753    753             753
#
#       Genres  Last Updated  Current Ver  Android Ver
# Type
# Free    8895          8895         8895         8895
# Paid     753           753          753          753

# %%
ps_data.query("Type!='Free' & Type!='Paid' ")
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
ps_data.at[8667,'Type']='Paid'
ps_data.at[9990,'Type']='Free'
ps_data.groupby('Type').count()
# Out:
#        App  Category  Rating  Reviews  Size  Installs  Price  Content Rating  \
# Type
# Free  8895      8895    8895     8895  8895      8895   8895            8895
# Paid   753       753     753      753   753       753    753             753
#
#       Genres  Last Updated  Current Ver  Android Ver
# Type
# Free    8895          8895         8895         8895
# Paid     753           753          753          753

# %%
size_of_groups=[9592,766]

# %% [markdown]
# # Here we can see that 92.22% apps are free and 7.78% are paid apps on Google Play Store, so we can say that Most of the apps are free on Google Play Store.

# %% [markdown]
# # Installs vs Rating

# %%
sns.lmplot(x='Rating',y='Installs',data=ps_data,x_estimator=np.mean)

# %% [markdown]
# # Above graph confirms that the apps with highest number of installs have the highest number of Ratings.

# %% [markdown]
# # Number of installed Applications according to content Rating

# %%
labels = ['Adults only 18+', 'Everyone', 'Everyone 10+' ,'Mature 17+', 'Teen']
sizes = [3 ,8382 , 373,  447 ,1143]

fig1, ax1 = plt.subplots()
fig1.set_size_inches(6,6)
myexplode = [0, 0, 0, 0,0.2]
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=0, explode = myexplode)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


plt.savefig('real.png', bbox_inches = 'tight',
    pad_inches = 0)
myexplode = [0.2, 0, 0, 0]
plt.show()

# %% [markdown]
# # From the above pie_plot we can say that 81% Apps can be accessed by everyone

# %% [markdown]
# # Most Downloaded apps in Play Store Dataset

# %%
pd.DatetimeIndex(Merged_df['Last Updated']).year
# Out:
# Int64Index([2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018,
#             ...
#             2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018],
#            dtype='int64', name='Last Updated', length=35929)

# %%
# Creating the column for year
ps_data['Year'] =  pd.DatetimeIndex(ps_data['Last Updated']).year

# %%
Category_df=ps_data.groupby(['Category','Year']).count()
Category_df.reset_index(inplace=True)
Category_df = Category_df[['Category', 'Installs','Year']]
Category_df.head()
# Out:
#             Category  Installs    Year
# 0     ART_AND_DESIGN        12  2017.0
# 1     ART_AND_DESIGN        51  2018.0
# 2  AUTO_AND_VEHICLES         1  2014.0
# 3  AUTO_AND_VEHICLES         3  2016.0
# 4  AUTO_AND_VEHICLES         7  2017.0

# %%
import plotly.express as px

# %%
# Plotting the barplot with Installs on x-axis and Year on y-axis and grouping them with category
fig = px.bar(Category_df, x='Installs', y='Year',color='Category',orientation='h',barmode='relative',text='Installs',
             title='Most Downloaded apps in Play Store Dataset',height=500,)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="76993b2c-6676-43dc-83d5-e17a7c82f45c" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76993b2c-6676-43dc-83d5-e17a7c82f45c")) {                    Plotly.newPlot(                        "76993b2c-6676-43dc-83d5-e17a7c82f45c",                        [{"alignmentgroup":"True","hovertemplate":"Category=ART_AND_DESIGN<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"ART_AND_DESIGN","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ART_AND_DESIGN","offsetgroup":"ART_AND_DESIGN","orientation":"h","showlegend":true,"text":[12.0,51.0],"textposition":"auto","x":[12,51],"xaxis":"x","y":[2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=AUTO_AND_VEHICLES<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"AUTO_AND_VEHICLES","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"AUTO_AND_VEHICLES","offsetgroup":"AUTO_AND_VEHICLES","orientation":"h","showlegend":true,"text":[1.0,3.0,7.0,74.0],"textposition":"auto","x":[1,3,7,74],"xaxis":"x","y":[2014.0,2016.0,2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=BEAUTY<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"BEAUTY","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BEAUTY","offsetgroup":"BEAUTY","orientation":"h","showlegend":true,"text":[1.0,12.0,40.0],"textposition":"auto","x":[1,12,40],"xaxis":"x","y":[2016.0,2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=BOOKS_AND_REFERENCE<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"BOOKS_AND_REFERENCE","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"BOOKS_AND_REFERENCE","offsetgroup":"BOOKS_AND_REFERENCE","orientation":"h","showlegend":true,"text":[1.0,3.0,9.0,23.0,27.0,50.0,108.0],"textposition":"auto","x":[1,3,9,23,27,50,108],"xaxis":"x","y":[2011.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=BUSINESS<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"BUSINESS","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"BUSINESS","offsetgroup":"BUSINESS","orientation":"h","showlegend":true,"text":[1.0,1.0,4.0,7.0,24.0,38.0,82.0,263.0],"textposition":"auto","x":[1,1,4,7,24,38,82,263],"xaxis":"x","y":[2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=COMICS<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"COMICS","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"COMICS","offsetgroup":"COMICS","orientation":"h","showlegend":true,"text":[1.0,1.0,8.0,46.0],"textposition":"auto","x":[1,1,8,46],"xaxis":"x","y":[2015.0,2016.0,2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=COMMUNICATION<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"COMMUNICATION","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"COMMUNICATION","offsetgroup":"COMMUNICATION","orientation":"h","showlegend":true,"text":[1.0,3.0,10.0,19.0,22.0,56.0,204.0],"textposition":"auto","x":[1,3,10,19,22,56,204],"xaxis":"x","y":[2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=DATING<br>Installs=%{text}<br>Year=%{y}<extra></extra>","legendgroup":"DATING","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"DATING","offsetgroup":"DATING","orientation":"h","showlegend":true,"text":[2.0,15.0,154.0],"textposition":"auto","x":[2,15,154],"xaxis":"x","y":[2016.0,2017.0,2018.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate": ...

# %% [markdown]
# # Family Category has high number of Applications and if we move from one year to another then we can also see the change in number of apps.
